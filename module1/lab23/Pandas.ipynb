# %%
import pandas as pd

# %%
b = [14, 12, 2021]

# one diminsional

s1 = pd.Series(b, index = ["day", "month", "year"])

print(s1)
# Out:
# day        14
# month      12
# year     2021
# dtype: int64

# %%
s1["day"]
# Out:
# 14

# %%
import numpy as np

# %%
# panel is about 3 diminsionals


data = np.random.randint(1, 10, (5, 3, 2))

data = data.reshape(5, 6).T
df = pd.DataFrame(
    data=data,
    index=pd.MultiIndex.from_product([[2015, 2016, 2017], ['US', 'UK']]),
    columns=['item {}'.format(i) for i in range(1, 6)]
)

# %%
df
# Out:
#          item 1  item 2  item 3  item 4  item 5
# 2015 US       3       9       7       1       7
#      UK       9       8       7       2       7
# 2016 US       7       3       1       3       7
#      UK       6       5       4       6       7
# 2017 US       9       5       7       9       1
#      UK       4       4       3       7       6

# %%
import pandas as pd

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
d = {'col1':[1,2], 'col2':[3,4]}
df1=pd.DataFrame(d, index =[23,24], columns =("col1","col2"))
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df4=pd.DataFrame({'Parameter': ['data', 'index', 'columns', 'dtype', 'copy'],
                  'Description': ['data can be presented in ndarray, series, map, lists, dict, constants another DataFrame.',
'Index to be used for the resulting frame is Optional Default np.arange(n) if no index is passed.',
'For column labels, the optional default syntax is - np.arange(n). This is only true if no index is passed.',
'Data type of each column.','This parameter is used for copying of data, if the default is False.']})
df4
# Out:
#   Parameter                                        Description
# 0      data  data can be presented in ndarray, series, map,...
# 1     index  Index to be used for the resulting frame is Op...
# 2   columns  For column labels, the optional default syntax...
# 3     dtype                          Data type of each column.
# 4      copy  This parameter is used for copying of data, if...

# %%
data=pd.read_csv(r'/Users/akbare/Desktop/Use Case_Sales_data.xlsx - hubspot-crm-exports-all-deals-2.csv')
data
# Out:
#        Deal ID      Close Date          Deal Type  Number of times contacted  \
# 0   3355889269  11/16/20 10:40       New Business                        NaN
# 1   3355862528             NaN                NaN                       42.0
# 2   3355878870             NaN                NaN                        0.0
# 3   4813604910   3/31/21 13:06  Existing Business                       27.0
# 4   3974710472     1/1/21 4:56                NaN                       47.0
# ..         ...             ...                ...                        ...
# 84  5501441059   11/1/21 10:12       New Business                        6.0
# 85  5501240504   9/17/21 10:12       New Business                        8.0
# 86  4158463794    9/1/21 11:23       New Business                        0.0
# 87  5284691808    6/7/21 11:59       New Business                        3.0
# 88  4158249907    3/1/21 20:45       New Business                        NaN
#
# ...

# %%
data.dtypes
# Out:
# Deal ID                         int64
# Close Date                     object
# Deal Type                      object
# Number of times contacted     float64
# Number of Sales Activities    float64
# Create Date                    object
# Deal owner                     object
# Deal Stage                     object
# Geographic Region              object
# Amount                        float64
# dtype: object

# %%
data.shape
# Out:
# (89, 10)

# %%
data.describe()
# Out:
#             Deal ID  Number of times contacted  Number of Sales Activities  \
# count  8.900000e+01                  75.000000                   76.000000
# mean   4.407567e+09                  27.133333                   57.684211
# std    9.007028e+08                  28.861895                  143.988445
# min    3.349256e+09                   0.000000                    1.000000
# 25%    3.450923e+09                   8.000000                   11.000000
# 50%    4.169622e+09                  20.000000                   24.000000
# 75%    5.351420e+09                  42.500000                   61.750000
# max    6.087435e+09                 188.000000                 1234.000000
#
#              Amount
# count  8.900000e+01
# mean   1.394862e+05
# std    3.227833e+05
# min    1.000000e+00
# 25%    1.980469e+04
# 50%    4.227375e+04
# 75%    1.550000e+05
# max    2.800000e+06

# %%
data.mean()
# Out:
# /var/folders/cl/lbql31ls26l5z9t2g92jwx_m0000gn/T/ipykernel_69224/531903386.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()
# Deal ID                       4.407567e+09
# Number of times contacted     2.713333e+01
# Number of Sales Activities    5.768421e+01
# Amount                        1.394862e+05
# dtype: float64

# %%
data['Deal Type'," Number of this "]
# Out:
# 0          New Business
# 1                   NaN
# 2                   NaN
# 3     Existing Business
# 4                   NaN
#             ...
# 84         New Business
# 85         New Business
# 86         New Business
# 87         New Business
# 88         New Business
# Name: Deal Type, Length: 89, dtype: object

# %%
data.loc[2]
# Out:
# Deal ID                              3355878870
# Close Date                                  NaN
# Deal Type                                   NaN
# Number of times contacted                   0.0
# Number of Sales Activities                  2.0
# Create Date                       11/9/20 12:42
# Deal owner                       Mellisa Reilly
# Deal Stage                    Closed won (done)
# Geographic Region                           NaN
# Amount                                  97500.0
# Name: 2, dtype: object

# %%
data.loc[2:6]
# Out:
#       Deal ID     Close Date          Deal Type  Number of times contacted  \
# 2  3355878870            NaN                NaN                        0.0
# 3  4813604910  3/31/21 13:06  Existing Business                       27.0
# 4  3974710472    1/1/21 4:56                NaN                       47.0
# 5  3355847511    1/1/19 2:42                NaN                        8.0
# 6  5462213547  6/30/21 12:42       New Business                        NaN
#
#    Number of Sales Activities    Create Date      Deal owner  \
# 2                         2.0  11/9/20 12:42  Mellisa Reilly
# 3                        44.0  3/24/21 14:05       Tom Kelly
# 4                        68.0   1/12/21 4:55       Tom Kelly
# 5                        10.0  11/9/20 12:42       Tom Kelly
# 6                         NaN  6/15/21 12:42  Mellisa Reilly
#
#           Deal Stage Geographic Region    Amount
# 2  Closed won (done)               NaN   97500.0
# ...

# %%
data[data["Number of Sales Activities"]==1]
# Out:
#        Deal ID      Close Date     Deal Type  Number of times contacted  \
# 0   3355889269  11/16/20 10:40  New Business                        NaN
# 13  5613230474    7/31/21 7:24           NaN                        0.0
# 17  4432567983   3/11/21 19:00  New Business                        0.0
# 21  3355875603    4/27/21 9:02  New Business                        0.0
# 26  3355847522   1/12/21 10:19           NaN                        1.0
# 35  3355855833             NaN  New Business                        1.0
#
#     Number of Sales Activities    Create Date      Deal owner  \
# 0                          1.0  11/9/20 12:42       Tom Kelly
# 13                         1.0    7/5/21 7:24       Bob Coren
# 17                         1.0    3/2/21 0:44        Anna Dia
# 21                         1.0  11/9/20 12:42  Mellisa Reilly
# 26                         1.0  11/9/20 12:42       Tom Kelly
# 35                         1.0  11/9/20 12:42  Mellisa Reilly
#
# ...

# %%
data.at[2,'Deal Type']
# Out:
# nan

# %%
data.at[0, 'Number of times contacted']=1

# %%
data.at[2, 'Number of times contacted']+13
data
# Out:
#        Deal ID      Close Date          Deal Type  Number of times contacted  \
# 0   3355889269  11/16/20 10:40       New Business                        1.0
# 1   3355862528             NaN                NaN                       42.0
# 2   3355878870             NaN                NaN                        0.0
# 3   4813604910   3/31/21 13:06  Existing Business                       27.0
# 4   3974710472     1/1/21 4:56                NaN                       47.0
# ..         ...             ...                ...                        ...
# 84  5501441059   11/1/21 10:12       New Business                        6.0
# 85  5501240504   9/17/21 10:12       New Business                        8.0
# 86  4158463794    9/1/21 11:23       New Business                        0.0
# 87  5284691808    6/7/21 11:59       New Business                        3.0
# 88  4158249907    3/1/21 20:45       New Business                        NaN
#
# ...

# %%
data['New13']
