# %% [markdown]
# # Subsetting and Descriptive Stats
#
# ## Before your start:
#    - Remember that you just need to do one of the challenges.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in IronHack's database.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly: enjoy the process!
#
# #### Import all the necessary libraries here:

# %%
# import libraries here
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1
# #### In this challenge we will use the `Temp_States`  dataset.
#
# #### First import it into a dataframe called `temp`.

# %%
# your code here
temp = pd.read_csv(r'/Users/akbare/Desktop/IronhackDA/DAFT_212/module_2/Lab_10_Subsetting-and-Descriptive-Statistics/Temp_States.csv')

# %% [markdown]
# #### Print `temp`.

# %%
# your code here
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the *temp* dataframe. What types of data do we have? Comment your result.

# %%
# your code here
temp.dtypes
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %%
temp.describe()
# Out:
#        Temperature
# count     7.000000
# mean     15.158730
# std       6.695265
# min       3.333333
# 25%      11.944444
# 50%      17.222222
# 75%      19.722222
# max      22.222222

# %%
"""
your comments here
"""

# %% [markdown]
# #### Select the rows where state is New York.

# %%
# your code here
subset = (temp['State'] == 'New York')
temp.loc[subset]
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average temperature of cities in New York?

# %%
# your code here
temp.loc[subset].mean()
# Out:
# /var/folders/cl/lbql31ls26l5z9t2g92jwx_m0000gn/T/ipykernel_19078/2469308724.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   temp.loc[subset].mean()
# Temperature    10.740741
# dtype: float64

# %% [markdown]
# #### Which states and cities have a temperature above 15 degrees Celsius?

# %%
# your code here
subset = (temp['State'],temp['City'],temp['Temperature'] > 15)
subset
# Out:
# (0       New York
#  1       New York
#  2       New York
#  3    Connecticut
#  4    Connecticut
#  5     New Jersey
#  6     New Jersey
#  Name: State, dtype: object,
#  0           NYC
#  1        Albany
#  2       Buffalo
#  3      Hartford
#  4    Bridgeport
#  5        Treton
#  6        Newark
#  Name: City, dtype: object,
#  0     True
#  1    False
#  2    False
#  3     True
#  4    False
#  5     True
#  6     True
#  Name: Temperature, dtype: bool)

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degrees Celsius.

# %%
# your code here
subset=(temp['City'],temp['Temperature']>15)
subset
# Out:
# (0           NYC
#  1        Albany
#  2       Buffalo
#  3      Hartford
#  4    Bridgeport
#  5        Treton
#  6        Newark
#  Name: City, dtype: object,
#  0     True
#  1    False
#  2    False
#  3     True
#  4    False
#  5     True
#  6     True
#  Name: Temperature, dtype: bool)

# %% [markdown]
# #### Which cities have a temperature above 15 degrees Celcius and below 20 degrees Celsius?
#
# **Hint**: First, write the condition. Then, select the rows.

# %%
# your code here
temp['City'] == 'NYC','hartford',temp[['Temperature']]<15
# Out:
# (0     True
#  1    False
#  2    False
#  3    False
#  4    False
#  5    False
#  6    False
#  Name: City, dtype: bool,
#  'hartford',
#     Temperature
#  0        False
#  1         True
#  2         True
#  3        False
#  4         True
#  5        False
#  6        False)

# %% [markdown]
# Find each states mean and std

# %%
# your code here
temp.pivot_table(index=["State"],values=["Temperature"],aggfunc={'mean','std'})
# Out:
#             Temperature
#                    mean       std
# State
# Connecticut   15.833333  1.964186
# New Jersey    21.111111  1.571348
# New York      10.740741  8.133404

# %% [markdown]
# #  Challenge 2

# %% [markdown]
# #### Load the `employees` dataset into a dataframe. Call the dataframe `employees`.

# %%
# your code here
employees= pd.read_csv(r'/Users/akbare/Desktop/IronhackDA/DAFT_212/module_2/Lab_10_Subsetting-and-Descriptive-Statistics/Employees.csv')
employees
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 1           IT    Master  associate    Thomas      7      45
# 2        Admin    Master  associate     Diana     10      52
# 3        Admin    Master         VP  Manuella     15      33
# 4        Sales    Master    Analyst     Carla      6      38
# ..         ...       ...        ...       ...    ...     ...
# 495      Sales       PhD         VP    Calvin      2     119
# 496         HR    Master    Analyst    Dustin      6      67
# 497      Sales       PhD         VP   Winston     13      93
# 498         IT       PhD    Analyst      Earl     12     108
# 499      Sales    Master    Analyst     Alvin     13      48
#
# [500 rows x 6 columns]

# %% [markdown]
# #### Explore the data types of the `employees` dataframe. Comment your results.

# %%
# your code here
employees.dtypes
# Out:
# Department    object
# Education     object
# Title         object
# Name          object
# Years          int64
# Salary         int64
# dtype: object

# %%
"""
your comments here
"""

# %%
employees.describe()
# Out:
#             Years      Salary
# count  500.000000  500.000000
# mean     7.556000   73.528000
# std      4.465731   26.890061
# min      1.000000   30.000000
# 25%      3.000000   50.000000
# 50%      7.000000   72.000000
# 75%     11.250000   97.000000
# max     15.000000  120.000000

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your code here
employees['Salary'].mean()
# Out:
# 73.528

# %% [markdown]
# #### What's the highest salary?

# %%
# your code here
employees['Salary'].max()
# Out:
# 120

# %% [markdown]
# #### What's the lowest salary?

# %%
# your code here
employees['Salary'].min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your code here
employees.pivot_table(index=["Name"],values=["Salary"],aggfunc="min")
# Out:
#           Salary
# Name
#  Beverly     min
# Adam         min
# Alan         min
# Alejandra    min
# Alex         max
# ...          ...
# Wesley       min
# Will         min
# Winston      min
# Yin          min
# Zach         min
#
# [201 rows x 1 columns]

# %% [markdown]
# #### Find all the information about an employee called David.

# %%
# your code here
subset = (employees['Name'] == 'David')
employees.loc[subset]
# Out:
#     Department Education      Title   Name  Years  Salary
# 0        Admin    Master  associate  David      4      58
# 124         IT  Bachelor         VP  David      3      31

# %% [markdown]
# #### Could you return only David's salary?

# %%
# your code here
employees[employees['Name']=='David'][['Name','Salary']]
# Out:
#       Name  Salary
# 0    David      58
# 124  David      31

# %% [markdown]
# #### Print all the rows where job title is associate.

# %%
# your code here
subset = (employees['Title'] == 'associate')
employees.loc[subset]
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 1           IT    Master  associate    Thomas      7      45
# 2        Admin    Master  associate     Diana     10      52
# 7           HR    Master  associate     Carol     14      53
# 8        Admin       PhD  associate      Jean      8      50
# ..         ...       ...        ...       ...    ...     ...
# 477         HR       PhD  associate   Phillip     11     113
# 486         IT  Bachelor  associate       Jay     14      58
# 487         HR    Master  associate  Patricia     10     110
# 491      Admin       PhD  associate     Alice      8      37
# 494      Sales  Bachelor  associate   Vanessa     11     118
#
# [158 rows x 6 columns]

# %% [markdown]
# #### Print the first 3 rows of your dataframe.
# **Tip**: There are 2 ways to do it. Do it both ways.

# %%
# Method 1
# your code here
employees.head(3)
# Out:
#   Department Education      Title    Name  Years  Salary
# 0      Admin    Master  associate   David      4      58
# 1         IT    Master  associate  Thomas      7      45
# 2      Admin    Master  associate   Diana     10      52

# %%
# Method 2
# your code here
employees.iloc[:3]
# Out:
#   Department Education      Title    Name  Years  Salary
# 0      Admin    Master  associate   David      4      58
# 1         IT    Master  associate  Thomas      7      45
# 2      Admin    Master  associate   Diana     10      52

# %% [markdown]
# #### Find the employees whose title is associate and whose salary is above 55.

# %%
# your code here
employees[(employees['Title'] =='associate')&(employees['Salary']<55)]
# Out:
#     Department Education      Title      Name  Years  Salary
# 1           IT    Master  associate    Thomas      7      45
# 2        Admin    Master  associate     Diana     10      52
# 7           HR    Master  associate     Carol     14      53
# 8        Admin       PhD  associate      Jean      8      50
# 12       Admin  Bachelor  associate  Leonardo      1      46
# 15          HR       PhD  associate    Ingrid      1      44
# 29          HR    Master  associate    Melvin     15      52
# 44       Admin  Bachelor  associate    Arnold     13      53
# 53          IT       PhD  associate    Julian     12      33
# 68       Admin    Master  associate  Leonardo      5      32
# 79          IT    Master  associate  Mauricio      1      45
# 96          HR       PhD  associate     Robin      2      47
# 106      Admin  Bachelor  associate      Luke      4      30
# 114         IT    Master  associate     Carey     13      35
# ...

# %% [markdown]
# #### Group the employees by number of years of employment. What are the average salaries in each group?

# %%
# your code here
employees.groupby(["Years","Department"])[["Salary"]].mean()
# Out:
#                      Salary
# Years Department
# 1     Admin       81.250000
#       HR          79.400000
#       IT          69.454545
#       Sales       68.571429
# 2     Admin       79.571429
#       HR          72.000000
#       IT          68.000000
#       Sales       79.846154
# 3     Admin       74.222222
#       HR          82.272727
#       IT          67.352941
#       Sales       76.736842
# 4     Admin       69.800000
#       HR          78.909091
#       IT          97.666667
#       Sales       59.750000
# 5     Admin       66.875000
#       HR          73.750000
#       IT          87.250000
#       Sales       74.250000
# 6     Admin       70.750000
#       HR          75.642857
#       IT          64.714286
#       Sales       74.000000
# 7     Admin       87.000000
#       HR          69.000000
#       IT          71.444444
#       Sales       70.800000
# 8     Admin       58.333333
#       HR          86.750000
#       IT          66.250000
# ...

# %% [markdown]
# ####  What is the average salary per title?

# %%
# your code here
employees.groupby(["Title"])[["Salary"]].mean()
# Out:
#               Salary
# Title
# Analyst    73.703911
# VP         72.907975
# associate  73.968354

# %% [markdown]
# ####  Find the salary quartiles.

# %%
# your code here

# %% [markdown]
# #### Is the mean salary different per gender?

# %%
# your code here

# %% [markdown]
# #### Find the minimum, mean and maximum of all numeric columns for each company department.

# %%
# your code here
employees.pivot_table(index=["Department"],values=["Salary",'Years'],aggfunc={'max','min','mean'})
# Out:
#            Years
#              max      mean  min
# Department
# Admin       15.0  7.642276  1.0
# HR          15.0  7.172131  1.0
# IT          15.0  8.141791  1.0
# Sales       15.0  7.206612  1.0

# %% [markdown]
# #### Bonus Question:  for each department, compute the difference between the maximum and the minimum salary.
# **Hint**: try using `agg` or `apply` combined with `lambda` functions.

# %%
# your code here
employees.pivot_table(index=["Department"],values=["Salary"],aggfunc={'max','min'})
# Out:
#            Salary
#               max min
# Department
# Admin         120  30
# HR            119  30
# IT            120  30
# Sales         120  30

# %% [markdown]
# # Challenge 3
# #### Open the `Orders` dataset. Name your dataset `orders`.

# %%
# your code here
orders=pd.read_csv(r'Orders - Orders.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/cl/lbql31ls26l5z9t2g92jwx_m0000gn/T/ipykernel_18491/2126535924.py in <module>
#       1 # your code here
# ----> 2 orders=pd.read_csv(r'Orders - Orders.csv')
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %% [markdown]
# #### Explore your dataset by looking at the data types and summary statistics. Comment your results.

# %%
# your code here
orders.head()

# %%
"""
your comments here
"""

# %% [markdown]
# ####  What is the average purchase price?

# %%
# your code here
orders.decribe()

# %% [markdown]
# #### What are the highest and lowest purchase prices?

# %%
# your code here

# %% [markdown]
# #### Select all the customers from Spain.
# **Hint**: Remember that you are not asked to find orders from Spain but customers. A customer might have more than one order associated.

# %%
# your code here

# %% [markdown]
# #### How many customers do we have in Spain?

# %%
# your code here

# %% [markdown]
# #### Select all the customers who have bought more than 50 items.
# **Hint**: Remember that you are not asked to find orders with more than 50 items but customers who bought more than 50 items. A customer with two orders of 30 items each should appear in the selection.

# %%
# your code here

# %% [markdown]
# #### Select orders from Spain that include more than 50 items.

# %%
# your code here

# %% [markdown]
# #### Select all free orders.

# %%
# your code here

# %% [markdown]
# #### Select all orders whose description starts with `lunch bag`.
# **Hint**: use string functions.

# %%
# your code here

# %% [markdown]
# #### Select all `lunch bag` orders made in 2011.

# %%
# your code here

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your code here

# %% [markdown]
# #### Select all orders made in the month of August.

# %%
# your code here

# %% [markdown]
# #### Find the number of orders made by each country in the month of August.
# **Hint**: Use value_counts().

# %%
# your code here

# %% [markdown]
# #### What's the  average amount of money spent by country?

# %%
# your code here

# %% [markdown]
# #### What's the most expensive item?

# %%
# your code here

# %% [markdown]
# #### What is the average amount spent per year?

# %%
# your code here
