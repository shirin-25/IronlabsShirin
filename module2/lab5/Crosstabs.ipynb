# %%
# Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Import the moovies dataset

# %% [markdown]
# # https://www.kaggle.com/carolzhangdc/imdb-5000-movie-dataset

# %%
data=pd.read_csv(r'/Users/akbare/Downloads/movie_metadata.csv')
data
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# 2                         0.0                   161.0      Rory Kinnear
# 3                     22000.0                 23000.0    Christian Bale
# 4                       131.0                     NaN        Rob Walker
# ...                       ...                     ...               ...
# 5038                      2.0                   318.0     Daphne Zuniga
# 5039                      NaN                   319.0     Valorie Curry
# 5040                      0.0                     0.0     Maxwell Moody
# 5041                      0.0                   489.0     Daniel Henney
# 5042                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes        gross                           genres  \
# 0                     1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                    40000.0  309404152.0         Action|Adventure|Fantasy
# 2                    11000.0  200074175.0        Action|Adventure|Thriller
# 3                    27000.0  448130642.0                  Action|Thriller
# 4                      131.0          NaN                      Documentary
# ...                      ...          ...                              ...
# 5038                   637.0          NaN                     Comedy|Drama
# 5039                   841.0          NaN     Crime|Drama|Mystery|Thriller
# 5040                     0.0          NaN            Drama|Horror|Thriller
# 5041                   946.0      10443.0             Comedy|Drama|Romance
# 5042                    86.0      85222.0                      Documentary
#
#       ... num_user_for_reviews language  country  content_rating       budget  \
# 0     ...               3054.0  English      USA           PG-13  237000000.0
# 1     ...               1238.0  English      USA           PG-13  300000000.0
# 2     ...                994.0  English       UK           PG-13  245000000.0
# 3     ...               2701.0  English      USA           PG-13  250000000.0
# 4     ...                  NaN      NaN      NaN             NaN          NaN
# ...   ...                  ...      ...      ...             ...          ...
# 5038  ...                  6.0  English   Canada             NaN          NaN
# 5039  ...                359.0  English      USA           TV-14          NaN
# 5040  ...                  3.0  English      USA             NaN       1400.0
# 5041  ...                  9.0  English      USA           PG-13          NaN
# 5042  ...                 84.0  English      USA              PG       1100.0
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0         2009.0                  936.0        7.9          1.78
# 1         2007.0                 5000.0        7.1          2.35
# 2         2015.0                  393.0        6.8          2.35
# 3         2012.0                23000.0        8.5          2.35
# 4            NaN                   12.0        7.1           NaN
# ...          ...                    ...        ...           ...
# 5038      2013.0                  470.0        7.7           NaN
# 5039         NaN                  593.0        7.5         16.00
# 5040      2013.0                    0.0        6.3           NaN
# 5041      2012.0                  719.0        6.3          2.35
# 5042      2004.0                   23.0        6.6          1.85
#
#      movie_facebook_likes
# 0                   33000
# 1                       0
# 2                   85000
# 3                  164000
# 4                       0
# ...                   ...
# 5038                   84
# 5039                32000
# 5040                   16
# 5041                  660
# 5042                  456
#
# [5043 rows x 28 columns]

# %%
data.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %% [markdown]
# ### 2. Use crosstabs to show the number of moovies per country

# %%
pd.crosstab(data.country,data.movie_title,margins=True).All
# Out:
# country
# Afghanistan                1
# Argentina                  4
# Aruba                      1
# Australia                 55
# Bahamas                    1
#                         ...
# UK                       448
# USA                     3807
# United Arab Emirates       1
# West Germany               3
# All                     5038
# Name: All, Length: 66, dtype: int64

# %% [markdown]
# ### 3. Create a crosstab to show the number of films per director and genre splitted by country

# %%
pd.crosstab(data.country, data.director_name)
# Out:
# director_name         A. Raven Cruz  Aaron Hann  Aaron Schneider  \
# country
# Afghanistan                       0           0                0
# Argentina                         0           0                0
# Aruba                             0           0                0
# Australia                         0           0                0
# Bahamas                           0           0                0
# ...                             ...         ...              ...
# Turkey                            0           0                0
# UK                                0           0                0
# USA                               1           1                1
# United Arab Emirates              0           0                0
# West Germany                      0           0                0
#
# director_name         Aaron Seltzer  Abel Ferrara  Adam Brooks  Adam Carolla  \
# country
# Afghanistan                       0             0            0             0
# Argentina                         0             0            0             0
# Aruba                             0             0            0             0
# Australia                         0             0            0             0
# Bahamas                           0             0            0             0
# ...                             ...           ...          ...           ...
# Turkey                            0             0            0             0
# UK                                0             0            0             0
# USA                               1             1            0             1
# United Arab Emirates              0             0            0             0
# West Germany                      0             0            0             0
#
# director_name         Adam Goldberg  Adam Green  Adam Jay Epstein  ...  \
# country                                                            ...
# Afghanistan                       0           0                 0  ...
# Argentina                         0           0                 0  ...
# Aruba                             0           0                 0  ...
# Australia                         0           0                 0  ...
# Bahamas                           0           0                 0  ...
# ...                             ...         ...               ...  ...
# Turkey                            0           0                 0  ...
# UK                                0           0                 0  ...
# USA                               1           1                 1  ...
# United Arab Emirates              0           0                 0  ...
# West Germany                      0           0                 0  ...
#
# director_name         Zack Snyder  Zack Ward  Zackary Adler  Zak Penn  \
# country
# Afghanistan                     0          0              0         0
# Argentina                       0          0              0         0
# Aruba                           0          0              0         0
# Australia                       0          0              0         0
# Bahamas                         0          0              0         0
# ...                           ...        ...            ...       ...
# Turkey                          0          0              0         0
# UK                              0          0              1         1
# USA                             8          1              0         0
# United Arab Emirates            0          0              0         0
# West Germany                    0          0              0         0
#
# director_name         Zal Batmanglij  Zoran Lisinac  Álex de la Iglesia  \
# country
# Afghanistan                        0              0                   0
# Argentina                          0              0                   0
# Aruba                              0              0                   0
# Australia                          0              0                   0
# Bahamas                            0              0                   0
# ...                              ...            ...                 ...
# Turkey                             0              0                   0
# UK                                 1              0                   0
# USA                                1              1                   0
# United Arab Emirates               0              0                   0
# West Germany                       0              0                   0
#
# director_name         Émile Gaudreault  Éric Tessier  Étienne Faure
# country
# Afghanistan                          0             0              0
# Argentina                            0             0              0
# Aruba                                0             0              0
# Australia                            0             0              0
# Bahamas                              0             0              0
# ...                                ...           ...            ...
# Turkey                               0             0              0
# UK                                   0             0              0
# USA                                  0             0              0
# United Arab Emirates                 0             0              0
# West Germany                         0             0              0
#
# [65 rows x 2395 columns]

# %% [markdown]
# ### 4. Average duration of filmes grouped by color

# %%
pd.crosstab(data.genres, data.color, values=data.duration, margins_name='Total',aggfunc='mean')
# Out:
# color                                                Black and White  \
# genres
# Action                                                         111.0
# Action|Adventure                                                 NaN
# Action|Adventure|Animation|Comedy|Crime|Family|...               NaN
# Action|Adventure|Animation|Comedy|Drama|Family|...               NaN
# Action|Adventure|Animation|Comedy|Family                         NaN
# ...                                                              ...
# Sci-Fi|Thriller                                                  NaN
# Thriller                                                         NaN
# Thriller|War                                                   133.0
# Thriller|Western                                                85.0
# Western                                                          NaN
#
# color                                                    Color
# genres
# Action                                              107.444444
# Action|Adventure                                    112.636364
# Action|Adventure|Animation|Comedy|Crime|Family|...   95.000000
# Action|Adventure|Animation|Comedy|Drama|Family|...   96.000000
# Action|Adventure|Animation|Comedy|Family             91.500000
# ...                                                        ...
# Sci-Fi|Thriller                                     104.700000
# Thriller                                            103.350000
# Thriller|War                                               NaN
# Thriller|Western                                           NaN
# Western                                             106.000000
#
# [912 rows x 2 columns]

# %% [markdown]
# ### 5. Average number of likes per director (assuming that total film's likes are counted as a sum of actor's likes)

# %%
data['film_likes']=data['actor_1_facebook_likes']+data['actor_2_facebook_likes']+data['actor_3_facebook_likes']

# %%
data
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# 2                         0.0                   161.0      Rory Kinnear
# 3                     22000.0                 23000.0    Christian Bale
# 4                       131.0                     NaN        Rob Walker
# ...                       ...                     ...               ...
# 5038                      2.0                   318.0     Daphne Zuniga
# 5039                      NaN                   319.0     Valorie Curry
# 5040                      0.0                     0.0     Maxwell Moody
# 5041                      0.0                   489.0     Daniel Henney
# 5042                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes        gross                           genres  \
# 0                     1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                    40000.0  309404152.0         Action|Adventure|Fantasy
# 2                    11000.0  200074175.0        Action|Adventure|Thriller
# 3                    27000.0  448130642.0                  Action|Thriller
# 4                      131.0          NaN                      Documentary
# ...                      ...          ...                              ...
# 5038                   637.0          NaN                     Comedy|Drama
# 5039                   841.0          NaN     Crime|Drama|Mystery|Thriller
# 5040                     0.0          NaN            Drama|Horror|Thriller
# 5041                   946.0      10443.0             Comedy|Drama|Romance
# 5042                    86.0      85222.0                      Documentary
#
#       ... language country  content_rating       budget title_year  \
# 0     ...  English     USA           PG-13  237000000.0     2009.0
# 1     ...  English     USA           PG-13  300000000.0     2007.0
# 2     ...  English      UK           PG-13  245000000.0     2015.0
# 3     ...  English     USA           PG-13  250000000.0     2012.0
# 4     ...      NaN     NaN             NaN          NaN        NaN
# ...   ...      ...     ...             ...          ...        ...
# 5038  ...  English  Canada             NaN          NaN     2013.0
# 5039  ...  English     USA           TV-14          NaN        NaN
# 5040  ...  English     USA             NaN       1400.0     2013.0
# 5041  ...  English     USA           PG-13          NaN     2012.0
# 5042  ...  English     USA              PG       1100.0     2004.0
#
#       actor_2_facebook_likes imdb_score aspect_ratio  movie_facebook_likes  \
# 0                      936.0        7.9         1.78                 33000
# 1                     5000.0        7.1         2.35                     0
# 2                      393.0        6.8         2.35                 85000
# 3                    23000.0        8.5         2.35                164000
# 4                       12.0        7.1          NaN                     0
# ...                      ...        ...          ...                   ...
# 5038                   470.0        7.7          NaN                    84
# 5039                   593.0        7.5        16.00                 32000
# 5040                     0.0        6.3          NaN                    16
# 5041                   719.0        6.3         2.35                   660
# 5042                    23.0        6.6         1.85                   456
#
#      film_likes
# 0        2791.0
# 1       46000.0
# 2       11554.0
# 3       73000.0
# 4           NaN
# ...         ...
# 5038     1425.0
# 5039     1753.0
# 5040        0.0
# 5041     2154.0
# 5042      125.0
#
# [5043 rows x 29 columns]

# %%
like=pd.crosstab(data.director_name,data.film_likes, values=data.film_likes, aggfunc='sum',margins=True, margins_name='Total')

# %%
like
# Out:
# film_likes          0.0   2.0  4.0   5.0   6.0  7.0   8.0  10.0  11.0  12.0  \
# director_name
# A. Raven Cruz       NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN
# Aaron Hann          NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN
# Aaron Schneider     NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN
# Aaron Seltzer       NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN
# Abel Ferrara        NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN
# ...                 ...   ...  ...   ...   ...  ...   ...   ...   ...   ...
# Álex de la Iglesia  NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN
# Émile Gaudreault    NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN
# Éric Tessier        NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN
# Étienne Faure       NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN
# Total               0.0  10.0  8.0  30.0  12.0  7.0  16.0  10.0  22.0  24.0
#
# film_likes          ...  120000.0  137622.0  139000.0  166898.0  260808.0  \
# director_name       ...
# A. Raven Cruz       ...       NaN       NaN       NaN       NaN       NaN
# Aaron Hann          ...       NaN       NaN       NaN       NaN       NaN
# Aaron Schneider     ...       NaN       NaN       NaN       NaN       NaN
# Aaron Seltzer       ...       NaN       NaN       NaN       NaN       NaN
# Abel Ferrara        ...       NaN       NaN       NaN       NaN       NaN
# ...                 ...       ...       ...       ...       ...       ...
# Álex de la Iglesia  ...       NaN       NaN       NaN       NaN       NaN
# Émile Gaudreault    ...       NaN       NaN       NaN       NaN       NaN
# Éric Tessier        ...       NaN       NaN       NaN       NaN       NaN
# Étienne Faure       ...       NaN       NaN       NaN       NaN       NaN
# Total               ...  120000.0  137622.0  139000.0  166898.0  260808.0
#
# film_likes          261875.0  283000.0  301748.0  655000.0       Total
# director_name
# A. Raven Cruz            NaN       NaN       NaN       NaN      1094.0
# Aaron Hann               NaN       NaN       NaN       NaN       406.0
# Aaron Schneider          NaN       NaN       NaN       NaN     16970.0
# Aaron Seltzer            NaN       NaN       NaN       NaN      4598.0
# Abel Ferrara             NaN       NaN       NaN       NaN      2198.0
# ...                      ...       ...       ...       ...         ...
# Álex de la Iglesia       NaN       NaN       NaN       NaN       702.0
# Émile Gaudreault         NaN       NaN       NaN       NaN       917.0
# Éric Tessier             NaN       NaN       NaN       NaN        72.0
# Étienne Faure            NaN       NaN       NaN       NaN        19.0
# Total               261875.0  283000.0  301748.0  655000.0  44334843.0
#
# [2386 rows x 3427 columns]

# %%
like[['Total']]
# Out:
# film_likes               Total
# director_name
# A. Raven Cruz           1094.0
# Aaron Hann               406.0
# Aaron Schneider        16970.0
# Aaron Seltzer           4598.0
# Abel Ferrara            2198.0
# ...                        ...
# Álex de la Iglesia       702.0
# Émile Gaudreault         917.0
# Éric Tessier              72.0
# Étienne Faure             19.0
# Total               44334843.0
#
# [2386 rows x 1 columns]
